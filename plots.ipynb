# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# GINGER ke vs 
data = np.array([
    [2024, 55.0],
    [2023, 42.0],
    [2022, 60.0],
    [2021, 188.0],
    [2020, 293.5],
    [2019, 307.5],
    [2018, 349.0],
    [2017, 428.0],
    [2016, 502.0],
    [2015, 506.0],
    [2014, 448.5],
    [2013, 370.0],
    [2012, 357.0]
    ])

# %%
np.sum(data[:,1])/1000
# Out:
# 3.9065

# %%
plt.figure(figsize=(10,5))
plt.bar(data[:,0], data[:,1], label="GINGER")
plt.xlabel('[year]')
plt.ylabel('[ke]')
plt.legend()
plt.show()
